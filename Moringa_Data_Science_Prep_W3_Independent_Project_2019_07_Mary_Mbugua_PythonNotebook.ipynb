# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryMbugua109/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Mary_Mbugua_PythonNotebook.ipynb/blob/main/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Mary_Mbugua_PythonNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA PREPARATION

# %%
#import numpy as np
import pandas as pd
import numpy as np

#Loading the first dataset that contains an excel workbook
cells_geo_description = pd.read_excel('cells_geo_description.xlsx')
cells_geo_description

# %%
# Loading the cells_geo dataset
cells_geo=pd.read_csv("/content/cells_geo.csv", delimiter=';', index_col=0)
cells_geo
# Out:
#         VILLES      STATUS LOCALISATION  ...          AREA     CELL_ID   SITE_CODE
# 0       ADJAME  In Service      ABIDJAN  ...           NaN  fbb2e75af3  0bb492ef17
# 1       ADJAME  In Service      ABIDJAN  ...           NaN  1502501d78  0bb492ef17
# 2       ADJAME  In Service      ABIDJAN  ...           NaN  0c2e182a0c  0bb492ef17
# 3      ASSINIE  In Service    INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service    INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...        ...         ...          ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
#Loading the CDR Description file 
CDR_description= pd.read_excel('/content/CDR_description.xlsx')
CDR_description
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
#Loading the Telcom_dataset(1) file
Telcom_dataset= pd.read_csv('Telcom_dataset.csv',delimiter=',',index_col=0)
Telcom_dataset
# Out:
#          VALUE               DATETIME  ...     CELL_ID     SITE_ID
# PRODUTC                                ...
# Voice        0  2012-05-06 23:04:37.0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# sms          0  2012-05-06 23:05:25.0  ...  /+cKZKIp41  /+cKZKIp41
# sms         25  2012-05-06 23:05:41.0  ...  /u0FSD+ahi  /u0FSD+ahi
# Voice       56  2012-05-06 23:05:42.0  ...  +cNeJzsTp3  +cNeJzsTp3
# Voice       14  2012-05-06 23:06:29.0  ...  051KhYDCpv  051KhYDCpv
# ...        ...                    ...  ...         ...         ...
# sms        100  2012-05-07 00:01:54.0  ...  0c2371d9bc  1e751d08a4
# Voice        1  2012-05-07 00:01:54.0  ...  5fb791cf56  65efe2bc62
# Voice        0  2012-05-07 00:01:54.0  ...  7773627c12  9ef9616350
# Voice        0  2012-05-07 00:01:54.0  ...  3f4af49d6c  969b8d0e39
# Voice        7  2012-05-07 00:01:54.0  ...  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 9 columns]

# %%
#Loading the Telcom_dataset(2) file to our directory
Telcom_dataset2= pd.read_csv('/content/Telcom_dataset.csv',index_col=0)
Telcom_dataset2
# Out:
#          VALUE               DATETIME  ...     CELL_ID     SITE_ID
# PRODUTC                                ...
# Voice        0  2012-05-06 23:04:37.0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# sms          0  2012-05-06 23:05:25.0  ...  /+cKZKIp41  /+cKZKIp41
# sms         25  2012-05-06 23:05:41.0  ...  /u0FSD+ahi  /u0FSD+ahi
# Voice       56  2012-05-06 23:05:42.0  ...  +cNeJzsTp3  +cNeJzsTp3
# Voice       14  2012-05-06 23:06:29.0  ...  051KhYDCpv  051KhYDCpv
# ...        ...                    ...  ...         ...         ...
# sms        100  2012-05-07 00:01:54.0  ...  0c2371d9bc  1e751d08a4
# Voice        1  2012-05-07 00:01:54.0  ...  5fb791cf56  65efe2bc62
# Voice        0  2012-05-07 00:01:54.0  ...  7773627c12  9ef9616350
# Voice        0  2012-05-07 00:01:54.0  ...  3f4af49d6c  969b8d0e39
# Voice        7  2012-05-07 00:01:54.0  ...  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 9 columns]

# %%
#Loading the Telcom dataset 3 file to our working directory
Telcom_dataset3=pd.read_csv('/content/Telcom_dataset3.csv',index_col=0)
Telcom_dataset3
# Out:
#          VALUE              DATE_TIME  ...      CELLID     SIET_ID
# PRODUCT                                ...
# Voice       61  2012-05-08 23:01:28.0  ...  +38u2u/rfx  +38u2u/rfx
# sms          0  2012-05-08 23:01:31.0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# Voice       10  2012-05-08 23:02:59.0  ...  +ZaaZozy/+  +ZaaZozy/+
# sms          0  2012-05-08 23:03:04.0  ...  +cNeJzsTp3  +cNeJzsTp3
# Voice       22  2012-05-08 23:03:16.0  ...  /eeMklgyJA  /eeMklgyJA
# ...        ...                    ...  ...         ...         ...
# Voice        0  2012-05-09 00:01:43.0  ...  2aa04dcab7  f7d63a29e5
# Voice       62  2012-05-09 00:01:43.0  ...  7f1f2f889f  b4ddb9e93c
# Voice       32  2012-05-09 00:01:43.0  ...  a4731e780e  d68260ef50
# Voice       30  2012-05-09 00:01:43.0  ...  98ed726da2  b4130b54ab
# Voice       60  2012-05-09 00:01:43.0  ...  1c11a2fcbb  6d70dae094
#
# [5001 rows x 9 columns]

# %% [markdown]
# 1.MERGING

# %%
#Now that we have loaded the files, we will merge them accordingly.
#1.Merging.
 #the cells_geo and CDR description dataframes that contains similar columns
CDR_Cells=pd.concat([cells_geo_description,CDR_description],axis=0,ignore_index=True)
CDR_Cells
# Out:
#         Column name   Format
# 0            VILLES   String
# 1            STATUS   String
# 2      LOCALISATION   String
# 3        DECOUPZONE   String
# 4          ZONENAME   String
# 5         LONGITUDE    Float
# 6          LATITUDE    Float
# 7            REGION   String
# 8              AREA   String
# 9           CELL_ID   String
# 10        SITE_CODE   String
# 11          PRODUCT   String
# 12            VALUE  Integer
# 13        DATE_TIME   String
# 14     CELL_ON_SITE  Integer
# 15  DW_A_NUMBER_INT   String
# 16  DW_B_NUMBER_INT   String
# 17        COUNTRY_A   String
# 18        COUNTRY_B   String
# 19          CELL_ID   String
# 20          SITE_ID   String

# %%
#1.1Merging the 3 Telcom_datasets and cells_geo dataset
Telcom_dataset123=pd.concat([Telcom_dataset,Telcom_dataset2,Telcom_dataset3])
Telcom_dataset123
# Out:
#        VALUE               DATETIME  ...      CELLID     SIET_ID
# Voice      0  2012-05-06 23:04:37.0  ...         NaN         NaN
# sms        0  2012-05-06 23:05:25.0  ...         NaN         NaN
# sms       25  2012-05-06 23:05:41.0  ...         NaN         NaN
# Voice     56  2012-05-06 23:05:42.0  ...         NaN         NaN
# Voice     14  2012-05-06 23:06:29.0  ...         NaN         NaN
# ...      ...                    ...  ...         ...         ...
# Voice      0                    NaN  ...  2aa04dcab7  f7d63a29e5
# Voice     62                    NaN  ...  7f1f2f889f  b4ddb9e93c
# Voice     32                    NaN  ...  a4731e780e  d68260ef50
# Voice     30                    NaN  ...  98ed726da2  b4130b54ab
# Voice     60                    NaN  ...  1c11a2fcbb  6d70dae094
#
# [15003 rows x 12 columns]

# %% [markdown]
# 2.DATA PREPARATION
# (a). Checking for missing values

# %%
#Checking for missing values in each dataset
cells_geo_description.isnull().sum()
# Out:
# Column name    0
# Description    0
# Format         0
# dtype: int64

# %%
#Checking for missing values in cells geo dataset
cells_geo.isnull().sum()
# Out:
# VILLES           0
# STATUS          67
# LOCALISATION     0
# DECOUPZONE       0
# ZONENAME         6
# LONGITUDE        0
# LATITUDE         0
# REGION           0
# AREA            23
# CELL_ID          0
# SITE_CODE        0
# dtype: int64

# %%
#dropping the null values in cells geo
clean_cells_geo=cells_geo.dropna()
print(clean_cells_geo)
# Out:
#         VILLES      STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 23       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  f740406877  0f34c36ac5
# 24       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  959e54c8f7  0f34c36ac5
# 25       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  56b7e7000c  0f34c36ac5
# 26       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  bc51c17a6f  0f34c36ac5
# 27       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  e460975c9f  0f34c36ac5
# ...        ...         ...          ...  ...            ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
#checking for missing values in CDR_description
CDR_description.isnull().sum()
# Out:
# Column name    0
# Description    0
# Format         0
# dtype: int64

# %%
#Checking for missing values in the merged Telcomdataset 123
Telcom_dataset123.isnull().sum()
# Out:
# VALUE                  0
# DATETIME            5001
# CELL_ON_SITE           0
# DW_A_NUMBER_INT        0
# DW_B_NUMBER_INT        0
# COUNTRY_A              0
# COUNTRY_B              0
# CELL_ID             5001
# SITE_ID             6433
# DATE_TIME          10002
# CELLID             10002
# SIET_ID            10607
# dtype: int64

# %% [markdown]
# (b). Dropping columns

# %%
#We will now drop the unnecessary tables from the Telkom_dataset123
Telcom_dataset123.drop(['COUNTRY_A','COUNTRY_B','DW_A_NUMBER_INT','DW_B_NUMBER_INT','CELL_ON_SITE'],axis=1)
# Out:
#          VALUE               DATETIME  ...     CELL_ID     SITE_ID
# PRODUTC                                ...
# Voice        0  2012-05-06 23:04:37.0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# sms          0  2012-05-06 23:05:25.0  ...  /+cKZKIp41  /+cKZKIp41
# sms         25  2012-05-06 23:05:41.0  ...  /u0FSD+ahi  /u0FSD+ahi
# Voice       56  2012-05-06 23:05:42.0  ...  +cNeJzsTp3  +cNeJzsTp3
# Voice       14  2012-05-06 23:06:29.0  ...  051KhYDCpv  051KhYDCpv
# ...        ...                    ...  ...         ...         ...
# sms        100  2012-05-07 00:01:54.0  ...  0c2371d9bc  1e751d08a4
# Voice        1  2012-05-07 00:01:54.0  ...  5fb791cf56  65efe2bc62
# Voice        0  2012-05-07 00:01:54.0  ...  7773627c12  9ef9616350
# Voice        0  2012-05-07 00:01:54.0  ...  3f4af49d6c  969b8d0e39
# Voice        7  2012-05-07 00:01:54.0  ...  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 12 columns]

# %% [markdown]
# (b).Choosing specific columns from the Telcom_dataset123

# %%
#We will now choose one column from the duplicated columns that we will need 
#from the above table
Telcom_dataset123=Telcom_dataset[['VALUE','DATETIME','CELL_ID','SITE_ID']]
Telcom_dataset123
# Out:
#          VALUE               DATETIME     CELL_ID     SITE_ID
# PRODUTC
# Voice        0  2012-05-06 23:04:37.0  /TJNe+Mmtu  /TJNe+Mmtu
# sms          0  2012-05-06 23:05:25.0  /+cKZKIp41  /+cKZKIp41
# sms         25  2012-05-06 23:05:41.0  /u0FSD+ahi  /u0FSD+ahi
# Voice       56  2012-05-06 23:05:42.0  +cNeJzsTp3  +cNeJzsTp3
# Voice       14  2012-05-06 23:06:29.0  051KhYDCpv  051KhYDCpv
# ...        ...                    ...         ...         ...
# sms        100  2012-05-07 00:01:54.0  0c2371d9bc  1e751d08a4
# Voice        1  2012-05-07 00:01:54.0  5fb791cf56  65efe2bc62
# Voice        0  2012-05-07 00:01:54.0  7773627c12  9ef9616350
# Voice        0  2012-05-07 00:01:54.0  3f4af49d6c  969b8d0e39
# Voice        7  2012-05-07 00:01:54.0  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 4 columns]

# %% [markdown]
# (c).Selecting specific columns in CDR_Cells table

# %%
CDR_Cells.loc[[4,5,6,7,8,11,13]]
# Out:
#    Column name  Format
# 4     ZONENAME  String
# 5    LONGITUDE   Float
# 6     LATITUDE   Float
# 7       REGION  String
# 8         AREA  String
# 11     PRODUCT  String
# 13   DATE_TIME  String

# %% [markdown]
# 3.ANALYSIS
# Using questionnares

# %%
#Which ones were the most used cities for the three days?
count=cells_geo['VILLES'].value_counts()
count.head(10)
# Out:
# COCODY          354
# YOPOUGON        295
# ABOBO           255
# MARCORY         141
# TREICHVILLE     132
# ADJAME          110
# YAMOUSSOUKRO    104
# PLATEAU         103
# KOUMASSI         91
# BOUAKE           65
# Name: VILLES, dtype: int64

# %%
#The three most used cities were COCODY,YOPOUGON,ABOBO
#The most used city in the three days was COCODY based on the output above.

# %%
#Most used products
Telcom_dataset123.groupby(by='PRODUTC').agg('count')
# Out:
#          VALUE  DATETIME  CELL_ID  SITE_ID
# PRODUTC
# Voice     2219      2219     2219     2218
# data       807       807      807       92
# sms       1975      1975     1975     1975

# %%
#The most used product was Voice,followed by sms then data
